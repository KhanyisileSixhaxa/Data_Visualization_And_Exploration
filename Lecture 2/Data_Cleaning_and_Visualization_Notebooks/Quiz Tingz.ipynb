# %% [markdown]
# # Code on the first quiz
#
# For this quiz, we were trying to describe the dataset and figure out how we can represent the data visually

# %%
# BASED ON https://machinelearningmastery.com/handle-missing-data-python/

import pandas as pd
import numpy as np
import missingno
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import seaborn as sns

# %%
df = pd.read_csv('same_means/same_means.csv')

# %%
df.describe()
# Out:
#                  x            y
# count  1846.000000  1846.000000
# mean     54.265695    47.835099
# std      16.713001    26.847766
# min      15.560750     0.015119
# 25%      41.073403    22.561073
# 50%      52.591269    47.594450
# 75%      67.277845    71.810778
# max      98.288123    99.694680

# %%
df.head()
# Out:
#   dataset_hidden        x        y
# 0        class_0  55.3846  97.1795
# 1        class_0  51.5385  96.0256
# 2        class_0  46.1538  94.4872
# 3        class_0  42.8205  91.4103
# 4        class_0  40.7692  88.3333

# %%
class_zero = df.loc[(df["dataset_hidden"] == "class_0")]
class_five = df.loc[(df["dataset_hidden"] == "class_5")]

# %%
sns.scatterplot(x=class_zero.x, y=class_zero.y, hue=class_zero.dataset_hidden).set_title('classes vs their pairs')
plt.savefig('classes.png')

# %%
sns.scatterplot(x=class_five.x, y=class_five.y, hue=class_five.dataset_hidden).set_title('classes vs their pairs')
plt.savefig('classes.png')

# %%
df2 = df.iloc[:-994]

# %%
sns.scatterplot(x=df2.x, y=df2.y, hue=df2.dataset_hidden).set_title('classes vs their pairs')
plt.savefig('classes.png')
